# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import csv

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# %%
f = open('BAD TEST Serch Terms.txt', 'r',encoding="utf8")

badTerms = f.read()

print(badTerms)

f.close()
# Out:
# ((scoresac.com) OR (executiveclub.nyc) OR (metlumber.com) OR (Scores) OR ((Star w/3 Light) OR “Starlight”) OR (Yackow) OR (Gans) OR (Nico) OR (Rosenbluth) OR (camera AND (deck OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (((night w/3 club) OR (gentlemen* w/3 club)) AND (Scores OR “Starlight” OR (“Star Light”))) OR (((HVAC w/10 construct*) OR HVAC) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((lease w/10 commence*) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((lease w/10 (“Year one”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((lease w/10 (“Year 2”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((lease w/10 (“Initial Term”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((commencement w/3 date) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((expir* /5 lease) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((“buyout” OR “buy-out” OR (“buy out”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((“directions” OR directional* OR directory OR directories) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club) OR (“Hard Rock”) OR “Boardwalk”)) OR ((“lightbox” OR (light w/3 box*)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (“kiosk” AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((rent* w/3 payment) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (((noise w/10 deck) OR outdoor*) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (solicit* AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((“logo” OR market* OR promot* OR advertis* OR trademark) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((Commenc* w/3 Date) AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas*)) OR (Commencement AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas*)) OR ((“Year 1”) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*)) OR ((“Year 2”) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*)) OR ((Initial w/3 Term) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*)) OR (((Terminat* OR expir* OR end) w/20 leas*) AND ((Star Light*) OR Starlight* OR Scores*)) OR ((Renew* w/10 lease) AND (“TTMA” OR Trump OR “Taj” OR (“Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwalk)) OR (((Open OR re-open) w/10 (Club OR Scores* OR (“Hard Rock”) OR Casino OR Hotel))) OR ((Clos* w/10 ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj”))) OR (Icahn AND ((Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*)) OR (Mellon AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*)) OR (Skillen AND (“TTMA” OR “Taj” OR (Trump “Hard Rock”) OR Boardwalk)) OR (Erickson AND (“TTMA” OR “Taj” OR Trump OR (“Hard Rock”)) AND (leas* OR operat* OR statement* OR result*)) OR (Moudatsos AND (“TTMA” OR “Taj” OR Trump OR (“Hard Rock”) OR leas*)) OR (Griffin AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*)) OR (Rivin AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR lea* OR negotiat*)) OR (trump.com OR taj.trump.com OR plaza.trump.com OR trumpintl.com) OR (((Complain* OR trouble* OR difficul*) w/20 (direction* OR locat* OR find)) AND ((Star Light*) OR Starlight* OR Scores* OR club OR (“Hard Rock”))) OR (Noise AND (deck OR outdoor* OR outside) AND ((Star Light*) OR Starlight* OR Scores*)) OR (Police AND ((Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwalk)) OR (((“Fire Department”) OR (“Fire Dept.”)) AND ((Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwa ...

# %%
print(type(badTerms))
# Out:
# <class 'str'>

# %%
def num_of_open_paren(word):
    word = str(word)
    counter = Counter(word)
    return counter['('] - counter[')']
    
def split_OR_Terms(terms):
    #value is -1 and not zero because there is usually a pair of "()" arround 
    #the whole set of terms so it causes the function not to work 
    
    openCount = -1
    elementCount = 0
    termList = []
    
    for word in terms.split():
        openCount+=num_of_open_paren(word)
        if (word != "OR"):
            try: termList[elementCount]  = termList[elementCount] + " " + word
            except: termList.append(word)
        elif (word == "OR" and openCount == 0):
            elementCount+=1
        elif (word == "OR" and openCount >= 1):
            try: termList[elementCount]  = termList[elementCount] + " " + word
            except: termList.append(word)
    termList[0] = termList[0][1:]
    termList[-1] = termList[-1][:-1]
    return termList

# %% [markdown]
# ((scoresac.com) OR (executiveclub.nyc) OR (metlumber.com) OR (Scores) OR ((Star w/3 Light) OR “Starlight”) OR (Yackow) OR (Gans) OR (Nico) OR (Rosenbluth) OR (camera AND (deck OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (((night w/3 club) OR (gentlemen* w/3 club)) AND (Scores OR “Starlight” OR (“Star Light”)))
#
#
# ((scoresac.com) OR (executiveclub.nyc) OR (metlumber.com) OR (Scores) OR ((Star w/3 Light) OR “Starlight”) OR (Yackow) OR (Gans) OR (Nico) OR (Rosenbluth) OR (camera AND (deck OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))
#
# (((night w/3 club) OR (gentlemen* w/3 club)) AND (Scores OR “Starlight” OR (“Star Light”)))

# %%
testTerms ="((scoresac.com) OR (executiveclub.nyc) OR (metlumber.com) OR (Scores) OR ((Star w/3 Light) OR “Starlight”) OR (Yackow) OR (Gans) OR (Nico) OR (Rosenbluth) OR (camera AND (deck OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (((night w/3 club) OR (gentlemen* w/3 club)) AND (Scores OR “Starlight” OR (“Star Light”)))"

testTerms2 ="(scoresac.com) OR (executiveclub.nyc) OR (metlumber.com) OR (Scores) OR ((Star w/3 Light) OR “Starlight”) OR (Yackow) OR (Gans) OR (Nico) OR (Rosenbluth) OR (camera AND (deck OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (((night w/3 club) OR (gentlemen* w/3 club)) AND (Scores OR “Starlight” OR (“Star Light”))) OR (((HVAC w/10 construct*) OR HVAC) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((lease w/10 commence*) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((lease w/10 (“Year one”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((lease w/10 (“Year 2”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((lease w/10 (“Initial Term”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((commencement w/3 date) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((expir* /5 lease) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((“buyout” OR “buy-out” OR (“buy out”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((“directions” OR directional* OR directory OR directories) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club) OR (“Hard Rock”) OR “Boardwalk”)) OR ((“lightbox” OR (light w/3 box*)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (“kiosk” AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((rent* w/3 payment) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (((noise w/10 deck) OR outdoor*) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (solicit* AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((“logo” OR market* OR promot* OR advertis* OR trademark) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((Commenc* w/3 Date) AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas*)) OR (Commencement AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas*)) OR ((“Year 1”) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*)) OR ((“Year 2”) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*)) OR ((Initial w/3 Term) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*)) OR (((Terminat* OR expir* OR end) w/20 leas*) AND ((Star Light*) OR Starlight* OR Scores*)) OR ((Renew* w/10 lease) AND (“TTMA” OR Trump OR “Taj” OR (“Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwalk)) OR (((Open OR re-open) w/10 (Club OR Scores* OR (“Hard Rock”) OR Casino OR Hotel))) OR ((Clos* w/10 ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj”))) OR (Icahn AND ((Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*)) OR (Mellon AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*)) OR (Skillen AND (“TTMA” OR “Taj” OR (Trump “Hard Rock”) OR Boardwalk)) OR (Erickson AND (“TTMA” OR “Taj” OR Trump OR (“Hard Rock”)) AND (leas* OR operat* OR statement* OR result*)) OR (Moudatsos AND (“TTMA” OR “Taj” OR Trump OR (“Hard Rock”) OR leas*)) OR (Griffin AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*)) OR (Rivin AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR lea* OR negotiat*)) OR (trump.com OR taj.trump.com OR plaza.trump.com OR trumpintl.com) OR (((Complain* OR trouble* OR difficul*) w/20 (direction* OR locat* OR find)) AND ((Star Light*) OR Starlight* OR Scores* OR club OR (“Hard Rock”))) OR (Noise AND (deck OR outdoor* OR outside) AND ((Star Light*) OR Starlight* OR Scores*)) OR (Police AND ((Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwalk)) OR (((“Fire Department”) OR (“Fire Dept.”)) AND ((Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwalk”)) OR ((Seminole OR Indian OR Tribe) AND ((Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwalk)) OR (licens* AND (DGE OR Gaming OR Commission OR CCC) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR ((“rent” OR (leas* w/3 payment*)) AND ((Star Light*) OR Starlight* OR Scores* OR Trump OR “TTMA” OR “Taj”) AND (timely OR untimely OR late)) OR (((HVAC w/10 construct*) OR “HVAC”) AND (Scores OR “Starlight” OR (“Star Light”) OR (“Hard Rock”) OR Boardwalk)) OR (camera AND deck) OR ((“lightbox” OR (light w/3 box*) OR kiosk) AND (Scores OR “Starlight” OR (“Star Light”) OR club OR (“Hard Rock”) OR Boardwalk)) OR ((“buyout” OR “buy-out” OR (“buy out”)) AND ((Star Light*) OR Starlight* OR Scores*)))"

testTerms3 ="(camera AND (deck OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club))) OR (((night w/3 club) OR (gentlemen* w/3 club)) AND (Scores OR “Starlight” OR (“Star Light”)))"

print(split_OR_Terms(testTerms2))
# Out:
# ['(scoresac.com)', '(executiveclub.nyc)', '(metlumber.com)', '(Scores)', '((Star w/3 Light) OR “Starlight”)', '(Yackow)', '(Gans)', '(Nico)', '(Rosenbluth)', '(camera AND (deck OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '(((night w/3 club) OR (gentlemen* w/3 club)) AND (Scores OR “Starlight” OR (“Star Light”)))', '(((HVAC w/10 construct*) OR HVAC) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((lease w/10 commence*) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((lease w/10 (“Year one”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((lease w/10 (“Year 2”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((lease w/10 (“Initial Term”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((commencement w/3 date) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((expir* /5 lease) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((“buyout” OR “buy-out” OR (“buy out”)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((“directions” OR directional* OR directory OR directories) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club) OR (“Hard Rock”) OR “Boardwalk”))', '((“lightbox” OR (light w/3 box*)) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '(“kiosk” AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((rent* w/3 payment) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '(((noise w/10 deck) OR outdoor*) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '(solicit* AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((“logo” OR market* OR promot* OR advertis* OR trademark) AND (Scores OR “Starlight” OR (“Star Light”) OR (gentlemen* w/3 club)))', '((Commenc* w/3 Date) AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas*))', '(Commencement AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas*))', '((“Year 1”) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*))', '((“Year 2”) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*))', '((Initial w/3 Term) AND ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj” OR leas*))', '(((Terminat* OR expir* OR end) w/20 leas*) AND ((Star Light*) OR Starlight* OR Scores*))', '((Renew* w/10 lease) AND (“TTMA” OR Trump OR “Taj” OR (“Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwalk))', '(((Open OR re-open) w/10 (Club OR Scores* OR (“Hard Rock”) OR Casino OR Hotel)))', '((Clos* w/10 ((Star Light*) OR Starlight* OR Scores* OR “TTMA” OR Trump OR “Taj”)))', '(Icahn AND ((Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*))', '(Mellon AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*))', '(Skillen AND (“TTMA” OR “Taj” OR (Trump “Hard Rock”) OR Boardwalk))', '(Erickson AND (“TTMA” OR “Taj” OR Trump OR (“Hard Rock”)) AND (leas* OR operat* OR statement* OR result*))', '(Moudatsos AND (“TTMA” OR “Taj” OR Trump OR (“Hard Rock”) OR leas*))', '(Griffin AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR leas* OR negotiat*))', '(Rivin AND (“TTMA” OR “Taj” OR Trump OR (Star Light*) OR Starlight* OR Scores* OR lea* OR negotiat*))', '(trump.com OR taj.trump.com OR plaza.trump.com OR trumpintl.com)', '(((Complain* OR trouble* OR difficul*) w/20 (direction* OR locat* OR find)) AND ((Star Light*) OR Starlight* OR Scores* OR club OR (“Hard Rock”)))', '(Noise AND (deck OR outdoor* OR outside) AND ((Star Light*) OR Starlight* OR Scores*))', '(Police AND ((Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardwalk))', '(((“Fire Department”) OR (“Fire Dept.”)) AND ((Star Light*) OR Starlight* OR Scores* OR (“Hard Rock”) OR Boardw ...

# %%
testList = [1,2,3,4]

testList2 = []

testList2[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-c6970caae0d5> in <module>
#       3 testList2 = []
#       4
# ----> 5 testList2[0]
#
# IndexError: list index out of range

# %%
print("{}{}".format(1,2))
# Out:
# 1   f 2

# %%
splitList = testTerms2.split()
newOpenCount = 0

for i in splitList:
    newOpenCount+=num_of_open_paren(i)
    print("word {} , num open {} , newOpenCount {}".format( i, num_of_open_paren(i),newOpenCount))
# Out:
# word (scoresac.com) , num open 0 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (executiveclub.nyc) , num open 0 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (metlumber.com) , num open 0 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Scores) , num open 0 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((Star , num open 2 , newOpenCount 2
# word w/3 , num open 0 , newOpenCount 2
# word Light) , num open -1 , newOpenCount 1
# word OR , num open 0 , newOpenCount 1
# word “Starlight”) , num open -1 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Yackow) , num open 0 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Gans) , num open 0 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Nico) , num open 0 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Rosenbluth) , num open 0 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (camera , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (deck , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (((night , num open 3 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (((HVAC , num open 3 , newOpenCount 3
# word w/10 , num open 0 , newOpenCount 3
# word construct*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word HVAC) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((lease , num open 2 , newOpenCount 2
# word w/10 , num open 0 , newOpenCount 2
# word commence*) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((lease , num open 2 , newOpenCount 2
# word w/10 , num open 0 , newOpenCount 2
# word (“Year , num open 1 , newOpenCount 3
# word one”)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((lease , num open 2 , newOpenCount 2
# word w/10 , num open 0 , newOpenCount 2
# word (“Year , num open 1 , newOpenCount 3
# word 2”)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((lease , num open 2 , newOpenCount 2
# word w/10 , num open 0 , newOpenCount 2
# word (“Initial , num open 1 , newOpenCount 3
# word Term”)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((commencement , num open 2 , newOpenCount 2
# word w/3 , num open 0 , newOpenCount 2
# word date) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((expir* , num open 2 , newOpenCount 2
# word /5 , num open 0 , newOpenCount 2
# word lease) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“buyout” , num open 2 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “buy-out” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“buy , num open 1 , newOpenCount 3
# word out”)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“directions” , num open 2 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word directional* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word directory , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word directories) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Boardwalk”)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“lightbox” , num open 2 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (light , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word box*)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (“kiosk” , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((rent* , num open 2 , newOpenCount 2
# word w/3 , num open 0 , newOpenCount 2
# word payment) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (((noise , num open 3 , newOpenCount 3
# word w/10 , num open 0 , newOpenCount 3
# word deck) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word outdoor*) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (solicit* , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“logo” , num open 2 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word market* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word promot* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word advertis* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word trademark) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((Commenc* , num open 2 , newOpenCount 2
# word w/3 , num open 0 , newOpenCount 2
# word Date) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (Star , num open 1 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Commencement , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (Star , num open 1 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“Year , num open 2 , newOpenCount 2
# word 1”) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “TTMA” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“Year , num open 2 , newOpenCount 2
# word 2”) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “TTMA” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((Initial , num open 2 , newOpenCount 2
# word w/3 , num open 0 , newOpenCount 2
# word Term) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “TTMA” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (((Terminat* , num open 3 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word expir* , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word end) , num open -1 , newOpenCount 2
# word w/20 , num open 0 , newOpenCount 2
# word leas*) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((Renew* , num open 2 , newOpenCount 2
# word w/10 , num open 0 , newOpenCount 2
# word lease) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Boardwalk)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (((Open , num open 3 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word re-open) , num open -1 , newOpenCount 2
# word w/10 , num open 0 , newOpenCount 2
# word (Club , num open 1 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word Scores* , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word (“Hard , num open 1 , newOpenCount 4
# word Rock”) , num open -1 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word Casino , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word Hotel))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((Clos* , num open 2 , newOpenCount 2
# word w/10 , num open 0 , newOpenCount 2
# word ((Star , num open 2 , newOpenCount 4
# word Light*) , num open -1 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word Starlight* , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word Scores* , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word “TTMA” , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word Trump , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word “Taj”))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Icahn , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word negotiat*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Mellon , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (Star , num open 1 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word negotiat*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Skillen , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (Trump , num open 1 , newOpenCount 3
# word “Hard , num open 0 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Boardwalk)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Erickson , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (leas* , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word operat* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word statement* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word result*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Moudatsos , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Griffin , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (Star , num open 1 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word leas* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word negotiat*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Rivin , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (“TTMA” , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (Star , num open 1 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word lea* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word negotiat*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (trump.com , num open 1 , newOpenCount 1
# word OR , num open 0 , newOpenCount 1
# word taj.trump.com , num open 0 , newOpenCount 1
# word OR , num open 0 , newOpenCount 1
# word plaza.trump.com , num open 0 , newOpenCount 1
# word OR , num open 0 , newOpenCount 1
# word trumpintl.com) , num open -1 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (((Complain* , num open 3 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word trouble* , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word difficul*) , num open -1 , newOpenCount 2
# word w/20 , num open 0 , newOpenCount 2
# word (direction* , num open 1 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word locat* , num open 0 , newOpenCount 3
# word OR , num open 0 , newOpenCount 3
# word find)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word club , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Noise , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (deck , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word outdoor* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word outside) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores*)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (Police , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Boardwalk)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (((“Fire , num open 3 , newOpenCount 3
# word Department”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Fire , num open 1 , newOpenCount 3
# word Dept.”)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Boardwalk”)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((Seminole , num open 2 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Indian , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Tribe) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Boardwalk)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (licens* , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (DGE , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Gaming , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Commission , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word CCC) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (gentlemen* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word club))) , num open -3 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“rent” , num open 2 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (leas* , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word payment*)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Trump , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “TTMA” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Taj”) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (timely , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word untimely , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word late)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (((HVAC , num open 3 , newOpenCount 3
# word w/10 , num open 0 , newOpenCount 3
# word construct*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “HVAC”) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Boardwalk)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word (camera , num open 1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word deck) , num open -1 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“lightbox” , num open 2 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (light , num open 1 , newOpenCount 3
# word w/3 , num open 0 , newOpenCount 3
# word box*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word kiosk) , num open -1 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word (Scores , num open 1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “Starlight” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Star , num open 1 , newOpenCount 3
# word Light”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word club , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“Hard , num open 1 , newOpenCount 3
# word Rock”) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Boardwalk)) , num open -2 , newOpenCount 0
# word OR , num open 0 , newOpenCount 0
# word ((“buyout” , num open 2 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word “buy-out” , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word (“buy , num open 1 , newOpenCount 3
# word out”)) , num open -2 , newOpenCount 1
# word AND , num open 0 , newOpenCount 1
# word ((Star , num open 2 , newOpenCount 3
# word Light*) , num open -1 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Starlight* , num open 0 , newOpenCount 2
# word OR , num open 0 , newOpenCount 2
# word Scores*))) , num open -3 , newOpenCount -1

# %%
#Testing count and Len 

testList = ['a', 'b','c','d']

for count,line in enumerate(testList):
    print("{} count , {} line".format(count,line))
    
    
print(len(testList))
# Out:
# 0 count , a line
# 1 count , b line
# 2 count , c line
# 3 count , d line
# 4

# %%
#Checking if you can manpulate a string inside of list with [:] the list slicing notation

testList = ['ab', 'bc','cd','de']

testList[0] = testList[0][1:]

print(testList[0])


print(testList[-1])
# Out:
# b
# de
